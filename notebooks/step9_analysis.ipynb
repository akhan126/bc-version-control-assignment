# %%
import pandas as pd

# Load processed data
df = pd.read_csv("../data/processed/dataset.csv")

df.head()
# Out:
#      year  arealand_sqmi  education_b15003_001e  education_b15003_lt9th  \
# 0  2025.0       1.377620                18341.0              334.843644
# 1  2025.0       0.511202                14235.0              118.099429
# 2  2025.0       0.277307                 7537.0              112.768853
# 3  2025.0       2.713007                39238.0             1345.894929
# 4  2025.0       1.353655                14997.0              309.443348
#
#    education_b15003_9th_to_12thnodiploma  education_b15003_hsgrad_and_ged  \
# 0                             193.926605                      2594.833214
# 1                              50.905669                       718.195275
# 2                              19.550000                       146.872565
# 3                            1189.355076                      3916.307706
# 4                             565.762779                      1999.228235
#
#    education_b15003_somecollegenodegree  education_b15003_021e  \
# ...

# %%
# Compute averages of numeric columns
numeric_means = df.select_dtypes("number").mean()

numeric_means.head(10)
# Out:
# year                                      2025.000000
# arealand_sqmi                                2.053131
# education_b15003_001e                    21405.913043
# education_b15003_lt9th                    1349.214889
# education_b15003_9th_to_12thnodiploma      962.044307
# education_b15003_hsgrad_and_ged           3781.014729
# education_b15003_somecollegenodegree      2388.491982
# education_b15003_021e                      993.765668
# education_b15003_022e                     6229.809178
# education_b15003_gradprofdegree           5701.224463
# dtype: float64
